# %%
# !pip install yt_dlp
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2025.5.22-py3-none-any.whl.metadata (174 kB)
# Downloading yt_dlp-2025.5.22-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 3.3/3.3 MB 27.5 MB/s eta 0:00:00
# Installing collected packages: yt_dlp
# Successfully installed yt_dlp-2025.5.22

# %%
import yt_dlp
import os
import sys
from pathlib import Path

# %%
url = "https://www.youtube.com/watch?v=8vXe48xQSoo"
output_path="./downloads"
quality="best"

# %%
# Create output directory if it doesn't exist
Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
ydl_opts = {
    'listformats': True,
    'quiet': False,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.extract_info(url, download=False)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading player 59b252b9-main
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# WARNING: [youtube] 8vXe48xQSoo: Some tv client https formats have been skipped as they are DRM protected. The current session may have an experiment that applies DRM to all videos on the tv client. See  https://github.com/yt-dlp/yt-dlp/issues/12563  for more details.
# WARNING: [youtube] 8vXe48xQSoo: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# [info] Available formats for 8vXe48xQSoo:
# ID  EXT   RESOLUTION FPS CH |   FILESIZE   TBR PROTO | VCODEC          VBR ACODEC     ASR MORE INFO
# ------------------------------------------------------------------------------------------------------------
# sb3 mhtml 48x27        0    |                  mhtml | images                             storyboard
# sb2 mhtml 80x45        0    |                  mhtml | images                             storyboard
# sb1 mhtml 160x90       0    |                  mhtml | images                             storyboard
# sb0 mhtml 320x180      0    |                  mhtml | images                             storyboard
# 233 mp4   audio only        |                  m3u8  | audio only          unknown        [en] Default, low
# 234 mp4   audio only        |                  m3u8  | audio only          unknown        [en] Default, high
# 602 mp4   256x144     15    | ~366.83MiB  187k m3u8  | vp09.00.10.08  187k video only
# 269 mp4   256x144     30    | ~495.00MiB  253k m3u8  | avc1.4D400C    253k video only
# 603 mp4   256x144     30    | ~381.36MiB  195k m3u8  | vp09.00.11.08  195k video only
# 229 mp4   426x240     30    | ~770.00MiB  393k m3u8  | avc1.4D4015    393k video only
# 604 mp4   426x240     30    | ~480.82MiB  245k m3u8  | vp09.00.20.08  245k video only
# 230 mp4   640x360     30    | ~  1.15GiB  600k m3u8  | avc1.4D401E    600k video only
# 18  mp4   640x360     30  2 |  703.02MiB  359k https | avc1.42001E         mp4a.40.2  44k [en] 360p
# 605 mp4   640x360     30    | ~912.85MiB  466k m3u8  | vp09.00.21.08  466k video only
# 231 mp4   854x480     30    | ~  1.96GiB 1027k m3u8  | avc1.4D401F   1027k video only
# 606 mp4   854x480     30    | ~  1.27GiB  662k m3u8  | vp09.00.30.08  662k video only
# 232 mp4   1280x720    30    | ~  3.33GiB 1741k m3u8  | avc1.4D401F   1741k video only
# 609 mp4   1280x720    30    | ~  2.23GiB 1167k m3u8  | vp09.00.31.08 1167k video only
# 270 mp4   1920x1080   30    | ~  6.03GiB 3151k m3u8  | avc1.640028   3151k video only
# 614 mp4   1920x1080   30    | ~  3.49GiB 1823k m3u8  | vp09.00.40.08 1823k video only

# %% [markdown]
# # Download Video

# %%
# Configure yt-dlp options with better format selection
ydl_opts = {
    'outtmpl': os.path.join(output_path, '%(title)s.%(ext)s'),
    'format': 'best[height<=1080]/best',  # Prefer combined formats, fallback to best
    'noplaylist': True,
    'writeinfojson': False,
    'writesubtitles': False,
    'writeautomaticsub': False,
    'ignoreerrors': False,
}

# Override format if user specified
if quality != "best":
    if quality == "worst":
        ydl_opts['format'] = 'worst'
    elif quality.endswith('p'):
        # For specific resolution like 720p, 480p
        height = quality[:-1]
        ydl_opts['format'] = f'best[height<={height}]/best'
    else:
        ydl_opts['format'] = quality

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    # Get video info first
    info = ydl.extract_info(url, download=False)
    title = info.get('title', 'Unknown')
    duration = info.get('duration', 'Unknown')
    uploader = info.get('uploader', 'Unknown')
    
    print(f"Title: {title}")
    print(f"Duration: {duration} seconds")
    print(f"Uploader: {uploader}")
    
    # Check file size estimate
    formats = info.get('formats', [])
    if formats:
        selected_format = None
        for fmt in formats:
            if fmt.get('vcodec') != 'none' and fmt.get('acodec') != 'none':
                selected_format = fmt
                break
        
        if selected_format and selected_format.get('filesize'):
            size_mb = selected_format['filesize'] / (1024 * 1024)
            print(f"Estimated size: {size_mb:.1f} MB")
    
    # Download the video
    print(f"\nStarting download...")
    ydl.extract_info(url, download=True)
    print(f"Download completed.")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# Title: Critical Role plays Daggerheart | Live One-Shot | Open Beta
# Duration: 16437 seconds
# Uploader: Critical Role
# Estimated size: 703.0 MB
#
# Starting download...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# [info] 8vXe48xQSoo: Downloading 1 format(s): 18
# [download] Destination: downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.mp4
# [download] 100% of  703.02MiB in 00:00:40 at 17.35MiB/s
# ⚠️ Download may have completed but file not found in expected location
# Check folder: c:\Users\deanv\Dropbox\0_Buas\2024-2025\Y2D\Demo Project\mlops-demo-project\notebooks\downloads

# %% [markdown]
# # Download Audio Only

# %%
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': os.path.join(output_path, '%(title)s.%(ext)s'),
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
    'noplaylist': True,
}

try:
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        print("Downloading audio...")
        ydl.download([url])
        print("✅ Audio download completed!")
except Exception as e:
    print(f"❌ Error downloading audio: {str(e)}")
# Out:
# Downloading audio...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# [info] 8vXe48xQSoo: Downloading 1 format(s): 251
# [download] Destination: downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.webm
# [download] 100% of  215.53MiB in 00:00:11 at 18.74MiB/s
# [ExtractAudio] Destination: downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.mp3
# Deleting original file downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.webm (pass -k to keep)
# ✅ Audio download completed!

# %% [markdown]
# # Download Audio only Mono WAV 16khz

# %%
sample_rate = 16000  # Set desired sample rate for WAV conversion

Path(output_path).mkdir(parents=True, exist_ok=True)

ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': os.path.join(output_path, '%(title)s.%(ext)s'),
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
        'preferredquality': None,
    }],
    'postprocessor_args': [
        '-ac', '1',  # Convert to mono
        '-ar', str(sample_rate),  # Set sample rate  
        '-acodec', 'pcm_s16le',  # 16-bit PCM
    ],
    'noplaylist': True,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(url, download=False)
    print(f"Title: {info.get('title', 'Unknown')}")
    print(f"Converting to mono WAV at {sample_rate} Hz...")
    ydl.download([url])
    print("✅ Download completed!")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# Title: Critical Role plays Daggerheart | Live One-Shot | Open Beta
# Converting to mono WAV at 16000 Hz...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8vXe48xQSoo
# [youtube] 8vXe48xQSoo: Downloading webpage
# [youtube] 8vXe48xQSoo: Downloading tv client config
# [youtube] 8vXe48xQSoo: Downloading tv player API JSON
# [youtube] 8vXe48xQSoo: Downloading ios player API JSON
# [youtube] 8vXe48xQSoo: Downloading m3u8 information
# [info] 8vXe48xQSoo: Downloading 1 format(s): 251
# [download] Destination: downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.webm
# [download] 100% of  215.53MiB in 00:00:12 at 17.45MiB/s
# [ExtractAudio] Destination: downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.wav
# Deleting original file downloads\Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.webm (pass -k to keep)
# ✅ Download completed!

# %% [markdown]
# # Chunk the audio into 30 second segments

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
# Chunk the audio into 30 second segments naively
from pydub import AudioSegment
from pydub.playback import play
import os

def chunk_audio(input_file, chunk_length=30):

    print(f"Chunking audio file: {input_file}")

    audio = AudioSegment.from_file(input_file)
    duration_ms = len(audio)
    chunk_length_ms = chunk_length * 1000

    print(f"Audio duration: {duration_ms / 1000:.2f} seconds")

    chunks = []
    for i in range(0, duration_ms, chunk_length_ms):
        print(f"Processing chunk from {i / 1000:.2f} to {(i + chunk_length_ms) / 1000:.2f} seconds")
        chunk = audio[i:i + chunk_length_ms]
        chunks.append(chunk)

    # Save chunks to files
    print(f"Saving {len(chunks)} chunks...")
    base_name = os.path.splitext(input_file)[0]
    for i, chunk in enumerate(chunks):
        print(f"Saving chunk {i}...")
        chunk.export(f"{base_name}_chunk_{i}_{chunk_length}_seconds.wav", format="wav")
        print(f"Chunk {i} saved as {base_name}_chunk_{i}.wav")

# %%
chunk_audio("downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.wav", chunk_length=300)
# Out:
# Chunking audio file: downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta.wav
# Audio duration: 16437.43 seconds
# Processing chunk from 0.00 to 300.00 seconds
# Processing chunk from 300.00 to 600.00 seconds
# Processing chunk from 600.00 to 900.00 seconds
# Processing chunk from 900.00 to 1200.00 seconds
# Processing chunk from 1200.00 to 1500.00 seconds
# Processing chunk from 1500.00 to 1800.00 seconds
# Processing chunk from 1800.00 to 2100.00 seconds
# Processing chunk from 2100.00 to 2400.00 seconds
# Processing chunk from 2400.00 to 2700.00 seconds
# Processing chunk from 2700.00 to 3000.00 seconds
# Processing chunk from 3000.00 to 3300.00 seconds
# Processing chunk from 3300.00 to 3600.00 seconds
# Processing chunk from 3600.00 to 3900.00 seconds
# Processing chunk from 3900.00 to 4200.00 seconds
# Processing chunk from 4200.00 to 4500.00 seconds
# Processing chunk from 4500.00 to 4800.00 seconds
# Processing chunk from 4800.00 to 5100.00 seconds
# Processing chunk from 5100.00 to 5400.00 seconds
# Processing chunk from 5400.00 to 5700.00 seconds
# Processing chunk from 5700.00 to 6000.00 seconds
# Processing chunk from 6000.00 to 6300.00 seconds
# Processing chunk from 6300.00 to 6600.00 seconds
# Processing chunk from 6600.00 to 6900.00 seconds
# Processing chunk from 6900.00 to 7200.00 seconds
# Processing chunk from 7200.00 to 7500.00 seconds
# Processing chunk from 7500.00 to 7800.00 seconds
# Processing chunk from 7800.00 to 8100.00 seconds
# Processing chunk from 8100.00 to 8400.00 seconds
# Processing chunk from 8400.00 to 8700.00 seconds
# Processing chunk from 8700.00 to 9000.00 seconds
# Processing chunk from 9000.00 to 9300.00 seconds
# Processing chunk from 9300.00 to 9600.00 seconds
# Processing chunk from 9600.00 to 9900.00 seconds
# Processing chunk from 9900.00 to 10200.00 seconds
# Processing chunk from 10200.00 to 10500.00 seconds
# Processing chunk from 10500.00 to 10800.00 seconds
# Processing chunk from 10800.00 to 11100.00 seconds
# Processing chunk from 11100.00 to 11400.00 seconds
# Processing chunk from 11400.00 to 11700.00 seconds
# Processing chunk from 11700.00 to 12000.00 seconds
# Processing chunk from 12000.00 to 12300.00 seconds
# Processing chunk from 12300.00 to 12600.00 seconds
# Processing chunk from 12600.00 to 12900.00 seconds
# Processing chunk from 12900.00 to 13200.00 seconds
# Processing chunk from 13200.00 to 13500.00 seconds
# Processing chunk from 13500.00 to 13800.00 seconds
# Processing chunk from 13800.00 to 14100.00 seconds
# Processing chunk from 14100.00 to 14400.00 seconds
# Processing chunk from 14400.00 to 14700.00 seconds
# Processing chunk from 14700.00 to 15000.00 seconds
# Processing chunk from 15000.00 to 15300.00 seconds
# Processing chunk from 15300.00 to 15600.00 seconds
# Processing chunk from 15600.00 to 15900.00 seconds
# Processing chunk from 15900.00 to 16200.00 seconds
# Processing chunk from 16200.00 to 16500.00 seconds
# Saving 55 chunks...
# Saving chunk 0...
# Chunk 0 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_0.wav
# Saving chunk 1...
# Chunk 1 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_1.wav
# Saving chunk 2...
# Chunk 2 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_2.wav
# Saving chunk 3...
# Chunk 3 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_3.wav
# Saving chunk 4...
# Chunk 4 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_4.wav
# Saving chunk 5...
# Chunk 5 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_5.wav
# Saving chunk 6...
# Chunk 6 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_6.wav
# Saving chunk 7...
# Chunk 7 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_7.wav
# Saving chunk 8...
# Chunk 8 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_8.wav
# Saving chunk 9...
# Chunk 9 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_9.wav
# Saving chunk 10...
# Chunk 10 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_10.wav
# Saving chunk 11...
# Chunk 11 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_11.wav
# Saving chunk 12...
# Chunk 12 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_12.wav
# Saving chunk 13...
# Chunk 13 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_13.wav
# Saving chunk 14...
# Chunk 14 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_14.wav
# Saving chunk 15...
# Chunk 15 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_15.wav
# Saving chunk 16...
# Chunk 16 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_16.wav
# Saving chunk 17...
# Chunk 17 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_17.wav
# Saving chunk 18...
# Chunk 18 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_18.wav
# Saving chunk 19...
# Chunk 19 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_19.wav
# Saving chunk 20...
# Chunk 20 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_20.wav
# Saving chunk 21...
# Chunk 21 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_21.wav
# Saving chunk 22...
# Chunk 22 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_22.wav
# Saving chunk 23...
# Chunk 23 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_23.wav
# Saving chunk 24...
# Chunk 24 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_24.wav
# Saving chunk 25...
# Chunk 25 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_25.wav
# Saving chunk 26...
# Chunk 26 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_26.wav
# Saving chunk 27...
# Chunk 27 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_27.wav
# Saving chunk 28...
# Chunk 28 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_28.wav
# Saving chunk 29...
# Chunk 29 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_29.wav
# Saving chunk 30...
# Chunk 30 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_30.wav
# Saving chunk 31...
# Chunk 31 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_31.wav
# Saving chunk 32...
# Chunk 32 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_32.wav
# Saving chunk 33...
# Chunk 33 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_33.wav
# Saving chunk 34...
# Chunk 34 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_34.wav
# Saving chunk 35...
# Chunk 35 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_35.wav
# Saving chunk 36...
# Chunk 36 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_36.wav
# Saving chunk 37...
# Chunk 37 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_37.wav
# Saving chunk 38...
# Chunk 38 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_38.wav
# Saving chunk 39...
# Chunk 39 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_39.wav
# Saving chunk 40...
# Chunk 40 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_40.wav
# Saving chunk 41...
# Chunk 41 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_41.wav
# Saving chunk 42...
# Chunk 42 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_42.wav
# Saving chunk 43...
# Chunk 43 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_43.wav
# Saving chunk 44...
# Chunk 44 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_44.wav
# Saving chunk 45...
# Chunk 45 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_45.wav
# Saving chunk 46...
# Chunk 46 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_46.wav
# Saving chunk 47...
# Chunk 47 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_47.wav
# Saving chunk 48...
# Chunk 48 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_48.wav
# Saving chunk 49...
# Chunk 49 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_49.wav
# Saving chunk 50...
# Chunk 50 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_50.wav
# Saving chunk 51...
# Chunk 51 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_51.wav
# Saving chunk 52...
# Chunk 52 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_52.wav
# Saving chunk 53...
# Chunk 53 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_53.wav
# Saving chunk 54...
# Chunk 54 saved as downloads/Critical Role plays Daggerheart ｜ Live One-Shot ｜ Open Beta_chunk_54.wav
